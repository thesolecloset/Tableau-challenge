# %%
import pandas as pd

# %%
citibikedf = pd.read_csv('Citibike3Months.csv')

# %%
citibikedf.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# trip_duration          object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
citibikedf.info
# Out:
# <bound method DataFrame.info of                  ride_id  rideable_type     started_at       ended_at  \
# 0       38F943EA06A4E54F  electric_bike   3/25/23 9:20   3/25/23 9:32
# 1       C76EFC4C3B771E88  electric_bike   3/15/23 7:55   3/15/23 8:07
# 2       02C7BC83975952E6  electric_bike   3/20/23 8:50   3/20/23 9:00
# 3       DB0FB572E0AA9C36  electric_bike   3/2/23 10:17   3/2/23 10:27
# 4       A238B2BDD1072D52  electric_bike    3/4/23 9:13    3/4/23 9:25
# ...                  ...            ...            ...            ...
# 239757  9549398286BB59B5    docked_bike  5/27/23 13:24  5/27/23 13:51
# 239758  AB0790683044D89E   classic_bike  5/18/23 17:12  5/18/23 17:25
# 239759  68226FA538A405CA   classic_bike   5/5/23 18:44   5/5/23 18:56
# 239760  CABAC21C0F0140A5   classic_bike  5/16/23 11:56  5/16/23 12:04
# 239761  4AABD797EF6F7BB2   classic_bike  5/30/23 11:04  5/30/23 11:13
#
#        trip_duration                            start_station_name  \
# ...

# %%
citibikedf
# Out:
#                  ride_id  rideable_type     started_at       ended_at  \
# 0       38F943EA06A4E54F  electric_bike   3/25/23 9:20   3/25/23 9:32
# 1       C76EFC4C3B771E88  electric_bike   3/15/23 7:55   3/15/23 8:07
# 2       02C7BC83975952E6  electric_bike   3/20/23 8:50   3/20/23 9:00
# 3       DB0FB572E0AA9C36  electric_bike   3/2/23 10:17   3/2/23 10:27
# 4       A238B2BDD1072D52  electric_bike    3/4/23 9:13    3/4/23 9:25
# ...                  ...            ...            ...            ...
# 239757  9549398286BB59B5    docked_bike  5/27/23 13:24  5/27/23 13:51
# 239758  AB0790683044D89E   classic_bike  5/18/23 17:12  5/18/23 17:25
# 239759  68226FA538A405CA   classic_bike   5/5/23 18:44   5/5/23 18:56
# 239760  CABAC21C0F0140A5   classic_bike  5/16/23 11:56  5/16/23 12:04
# 239761  4AABD797EF6F7BB2   classic_bike  5/30/23 11:04  5/30/23 11:13
#
#        trip_duration                            start_station_name  \
# ...
